# %% [markdown]
# # Data Mining and Neural Networks [Computational Task: 1]

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np;
import pandas as pd;
import matplotlib as mp;
from sklearn import preprocessing;
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score

# %%
data = pd.read_csv("Dataset.csv")

# %%
data.head()
# Out:
#          ID Cancer Type      1      2       3       4        5        6  \
# 0    842302           M  17.99  10.38  122.80  1001.0  0.11840  0.27760
# 1    842517           M  20.57  17.77  132.90  1326.0  0.08474  0.07864
# 2  84300903           M  19.69  21.25  130.00  1203.0  0.10960  0.15990
# 3  84348301           M  11.42  20.38   77.58   386.1  0.14250  0.28390
# 4  84358402           M  20.29  14.34  135.10  1297.0  0.10030  0.13280
#
#         7        8  ...     21     22      23      24      25      26      27  \
# 0  0.3001  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119
# 1  0.0869  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 2  0.1974  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 3  0.2414  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 4  0.1980  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
#
#        28      29       30
# 0  0.2654  0.4601  0.11890
# ...

# %%
ID = data['ID']

# %%
answer = data['Cancer Type']

# %%
data.rename(columns = {'Cancer Type':'Labels'}, inplace = True)

# %% [markdown]
# ### Number of malignant and benign cases respectively

# %%
Count_M = 0
Count_B = 0
UnIndentified = 0
for i in answer:
    if(i=='M'):
        Count_M = Count_M+1
    elif(i=='B'):
        Count_B = Count_B+1
    else:
        UnIndentified = UnIndentified+1
print("Number of malignant cases: ", Count_M)
print("Number of benign cases: ", Count_B)
print("UnIdentified: ", UnIndentified)
# Out:
# Number of malignant cases:  212
# Number of benign cases:  357
# UnIdentified:  0

# %%
a_mean=data.iloc[:,2:].mean().tolist()
a_var=data.iloc[:,2:].var().tolist()
a_std=data.iloc[:,2:].std().tolist()
ls=[a_mean,a_var,a_std]
ls=np.array(ls)
ls=ls.transpose()

# %%
R = pd.DataFrame(ls,
                      columns=["Mean",
                               "Variance",
                               "Standard Deviation"],
                      index=["Attribute 1",
                           "Attribute 2",
                           "Attribute 3",
                           "Attribute 4",
                           "Attribute 5",
                           "Attribute 6",
                           "Attribute 7",
                           "Attribute 8",
                           "Attribute 9",
                           "Attribute 10",
                             "Attribute 11",
                            "Attribute 12",
                            "Attribute 13",
                            "Attribute 14",
                            "Attribute 15",
                            "Attribute 16",
                            "Attribute 17",
                             "Attribute 18",
                            "Attribute 19",
                            "Attribute 20",
                            "Attribute 21",
                            "Attribute 22",
                            "Attribute 23",
                            "Attribute 24",
                            "Attribute 25",
                            "Attribute 26",
                            "Attribute 27",
                            "Attribute 28",
                            "Attribute 29",
                            "Attribute 30"]
                     )

# %%
print(R)
# Out:
#                     Mean       Variance  Standard Deviation
# Attribute 1    14.127292      12.418920            3.524049
# Attribute 2    19.289649      18.498909            4.301036
# Attribute 3    91.969033     590.440480           24.298981
# Attribute 4   654.889104  123843.554318          351.914129
# Attribute 5     0.096360       0.000198            0.014064
# Attribute 6     0.104341       0.002789            0.052813
# Attribute 7     0.088799       0.006355            0.079720
# Attribute 8     0.048919       0.001506            0.038803
# Attribute 9     0.181162       0.000752            0.027414
# Attribute 10    0.062798       0.000050            0.007060
# Attribute 11    0.405172       0.076902            0.277313
# Attribute 12    1.216853       0.304316            0.551648
# Attribute 13    2.866059       4.087896            2.021855
# Attribute 14   40.337079    2069.431583           45.491006
# Attribute 15    0.007041       0.000009            0.003003
# ...

# %%
M_Data = data.query('Labels == "M"')

# %%
M_Data = M_Data.iloc[:, 2:]

# %%
B_Data = data.query('Labels == "B"')

# %%
B_Data = B_Data.iloc[:, 2:]

# %%
a=M_Data.mean().tolist()
b=M_Data.var().tolist()
c=M_Data.std().tolist()
d=B_Data.mean().tolist()
e=B_Data.var().tolist()

# %%
f=B_Data.std().tolist()

# %%
l = [a,b,c,d,e,f]
l = np.array(l)
l=l.transpose()
l.shape
# Out:
# (30, 6)

# %%
Result = pd.DataFrame(l,
                      columns=["Mean of malignant",
                               "Variance of malignant",
                               "Standard Deviation of malignant",
                               "Mean of benign",
                               "Variance of benign",
                               "Standard Deviation of benign"],
                      index=["Attribute 1",
                           "Attribute 2",
                           "Attribute 3",
                           "Attribute 4",
                           "Attribute 5",
                           "Attribute 6",
                           "Attribute 7",
                           "Attribute 8",
                           "Attribute 9",
                           "Attribute 10",
                             "Attribute 11",
                            "Attribute 12",
                            "Attribute 13",
                            "Attribute 14",
                            "Attribute 15",
                            "Attribute 16",
                            "Attribute 17",
                             "Attribute 18",
                            "Attribute 19",
                            "Attribute 20",
                            "Attribute 21",
                            "Attribute 22",
                            "Attribute 23",
                            "Attribute 24",
                            "Attribute 25",
                            "Attribute 26",
                            "Attribute 27",
                            "Attribute 28",
                            "Attribute 29",
                            "Attribute 30"]
                     )

# %%
print(Result)
# Out:
#               Mean of malignant  Variance of malignant  \
# Attribute 1           17.462830              10.265431
# Attribute 2           21.604906              14.284393
# Attribute 3          115.365377             477.625870
# Attribute 4          978.376415          135378.355365
# Attribute 5            0.102898               0.000159
# Attribute 6            0.145188               0.002915
# Attribute 7            0.160775               0.005628
# Attribute 8            0.087990               0.001182
# Attribute 9            0.192909               0.000764
# Attribute 10           0.062680               0.000057
# Attribute 11           0.609083               0.119052
# Attribute 12           1.210915               0.233461
# Attribute 13           4.323929               6.597427
# Attribute 14          72.672406            3764.468961
# Attribute 15           0.006780               0.000008
# Attribute 16           0.032281               0.000338
# ...

# %% [markdown]
# ## Histograms

# %% [markdown]
# ### Normalization to its unit variance

# %%
data_norm = data.iloc[:, 2:]
print(data_norm.describe())
# Out:
#                 1           2           3            4           5  \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    14.127292   19.289649   91.969033   654.889104    0.096360
# std      3.524049    4.301036   24.298981   351.914129    0.014064
# min      6.981000    9.710000   43.790000   143.500000    0.052630
# 25%     11.700000   16.170000   75.170000   420.300000    0.086370
# 50%     13.370000   18.840000   86.240000   551.100000    0.095870
# 75%     15.780000   21.800000  104.100000   782.700000    0.105300
# max     28.110000   39.280000  188.500000  2501.000000    0.163400
#
#                 6           7           8           9          10  ...  \
# count  569.000000  569.000000  569.000000  569.000000  569.000000  ...
# mean     0.104341    0.088799    0.048919    0.181162    0.062798  ...
# std      0.052813    0.079720    0.038803    0.027414    0.007060  ...
# min      0.019380    0.000000    0.000000    0.106000    0.049960  ...
# ...

# %%
data_norm.head()
# Out:
#        1      2       3       4        5        6       7        8       9  \
# 0  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 2  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 3  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 4  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
#
#         10  ...     21     22      23      24      25      26      27      28  \
# 0  0.07871  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.05667  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.05999  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.09744  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.05883  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        29       30
# 0  0.4601  0.11890
# ...

# %% [markdown]
# As, We can see above the attributes are not normalised as the mean is not zero and the std is not equal to one.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
data_norm = sc.fit_transform(data)

# %%
data_norm = pd.DataFrame(data_norm,
                      columns=["radius",
                           "texture",
                           "perimeter",
                           "area",
                           "smoothness",
                           "compactness",
                           "concavity",
                           "concave points",
                           "symmetry",
                           "fractal dimension",
                              "Mean radius",
                           "Mean texture",
                           "Mean perimeter",
                           "Mean area",
                           "Mean smoothness",
                           "Mean compactness",
                           "Mean concavity",
                           "Mean concave points",
                           "Mean symmetry",
                           "Mean fractal dimension",
                              "Worst or Largest radius",
                           "Worst or Largest texture",
                           "Worst or Largest perimeter",
                           "Worst or Largest area",
                           "Worst or Largest smoothness",
                           "Worst or Largest compactness",
                           "Worst or Largest concavity",
                           "Worst or Largest concave points",
                           "Worst or Largest symmetry",
                           "Worst or Largest fractal dimension",
                              ]
                     )

# %%
print(data_norm.describe())
# Out:
#              radius       texture     perimeter          area    smoothness  \
# count  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02
# mean  -1.170710e-18  6.712069e-17  6.634022e-18 -4.292602e-18 -1.482899e-17
# std    1.000880e+00  1.000880e+00  1.000880e+00  1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00 -1.984504e+00 -1.454443e+00 -3.112085e+00
# 25%   -6.893853e-01 -7.259631e-01 -6.919555e-01 -6.671955e-01 -7.109628e-01
# 50%   -2.150816e-01 -1.046362e-01 -2.359800e-01 -2.951869e-01 -3.489108e-02
# 75%    4.693926e-01  5.841756e-01  4.996769e-01  3.635073e-01  6.361990e-01
# max    3.971288e+00  4.651889e+00  3.976130e+00  5.250529e+00  4.770911e+00
#
#         compactness     concavity  concave points      symmetry  \
# count  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean   1.287781e-17 -1.338511e-16   -7.804731e-17 -9.170559e-18
# std    1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# ...

# %%
data_norm.head()
# Out:
#      radius   texture  perimeter      area  smoothness  compactness  \
# 0  1.097064 -2.073335   1.269934  0.984375    1.568466     3.283515
# 1  1.829821 -0.353632   1.685955  1.908708   -0.826962    -0.487072
# 2  1.579888  0.456187   1.566503  1.558884    0.942210     1.052926
# 3 -0.768909  0.253732  -0.592687 -0.764464    3.283553     3.402909
# 4  1.750297 -1.151816   1.776573  1.826229    0.280372     0.539340
#
#    concavity  concave points  symmetry  fractal dimension  ...  \
# 0   2.652874        2.532475  2.217515           2.255747  ...
# 1  -0.023846        0.548144  0.001392          -0.868652  ...
# 2   1.363478        2.037231  0.939685          -0.398008  ...
# 3   1.915897        1.451707  2.867383           4.910919  ...
# 4   1.371011        1.428493 -0.009560          -0.562450  ...
#
#    Worst or Largest radius  Worst or Largest texture  \
# 0                 1.886690                 -1.359293
# 1                 1.805927                 -0.369203
# ...

# %% [markdown]
# The attributes are normalised as the mean is 0 and standard deviation is 1

# %%
data_norm['Labels'] = data['Labels']

# %%
data_norm
# Out:
#        radius   texture  perimeter      area  smoothness  compactness  \
# 0    1.097064 -2.073335   1.269934  0.984375    1.568466     3.283515
# 1    1.829821 -0.353632   1.685955  1.908708   -0.826962    -0.487072
# 2    1.579888  0.456187   1.566503  1.558884    0.942210     1.052926
# 3   -0.768909  0.253732  -0.592687 -0.764464    3.283553     3.402909
# 4    1.750297 -1.151816   1.776573  1.826229    0.280372     0.539340
# ..        ...       ...        ...       ...         ...          ...
# 564  2.110995  0.721473   2.060786  2.343856    1.041842     0.219060
# 565  1.704854  2.085134   1.615931  1.723842    0.102458    -0.017833
# 566  0.702284  2.045574   0.672676  0.577953   -0.840484    -0.038680
# 567  1.838341  2.336457   1.982524  1.735218    1.525767     3.272144
# 568 -1.808401  1.221792  -1.814389 -1.347789   -3.112085    -1.150752
#
#      concavity  concave points  symmetry  fractal dimension  ...  \
# ...

# %% [markdown]
# We now have normalized the attributes and merged the cancer type (label) at the end of the dataframe

# %%
 data_norm.to_csv('Normalized_data.csv', index = False)

# %% [markdown]
# ## 1NN and 3NN Classification and Evaluation

# %%
data_norm["Labels"] = np.where(data_norm["Labels"].str.contains("M"), 1, 0)

# %%
Y = data_norm['Labels'].to_numpy()
X = data_norm.iloc[:,0:30].to_numpy()

# %%
data_norm.head()
# Out:
#      radius   texture  perimeter      area  smoothness  compactness  \
# 0  1.097064 -2.073335   1.269934  0.984375    1.568466     3.283515
# 1  1.829821 -0.353632   1.685955  1.908708   -0.826962    -0.487072
# 2  1.579888  0.456187   1.566503  1.558884    0.942210     1.052926
# 3 -0.768909  0.253732  -0.592687 -0.764464    3.283553     3.402909
# 4  1.750297 -1.151816   1.776573  1.826229    0.280372     0.539340
#
#    concavity  concave points  symmetry  fractal dimension  ...  \
# 0   2.652874        2.532475  2.217515           2.255747  ...
# 1  -0.023846        0.548144  0.001392          -0.868652  ...
# 2   1.363478        2.037231  0.939685          -0.398008  ...
# 3   1.915897        1.451707  2.867383           4.910919  ...
# 4   1.371011        1.428493 -0.009560          -0.562450  ...
#
#    Worst or Largest texture  Worst or Largest perimeter  \
# 0                 -1.359293                    2.303601
# 1                 -0.369203                    1.535126
# ...

# %% [markdown]
# ### Using leave one out cross validation for calculating the accuracy of 1NN and 3NN

# %%
loo = LeaveOneOut()

# %%
KNN_1 = KNeighborsClassifier(n_neighbors=1)

# %%
KNN_3 = KNeighborsClassifier(n_neighbors=3)

# %%
accuracy_1nn = cross_val_score(KNN_1, X, Y, scoring='accuracy', cv = loo)
print('Accuracy of the 1NN classifier: %.3f (%.3f)' % (np.mean(accuracy_1nn), np.std(accuracy_1nn)))
# Out:
# Accuracy of the 1NN classifier: 0.951 (0.216)

# %%
accuracy_3nn = cross_val_score(KNN_3, X, Y, scoring='accuracy', cv = loo)
print('Accuracy of the 3NN classifier: %.3f (%.3f)' % (np.mean(accuracy_3nn), np.std(accuracy_3nn)))
# Out:
# Accuracy of the 3NN classifier: 0.965 (0.184)

# %% [markdown]
# As expected 3NN performs better than the 1NN algorithm
